# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=100) and learning rate is 0.0001 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=100
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=100
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  print(X_norm)
  
def run():
  learningRate=0.0001
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.0001
    init_b=0
    init_m=-0.5
    iterr=100
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("100 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 100:")
  plt.plot(range(100),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 48.25549999999999
# After iterrations= 100, error = 9.142907187253968e-07
# 9.142907187253968e-07
# 100 times updating iterrations regression line:
# ...

# %%
## Python library fit function LinearRegression() is used to compare our above regression line from GD model with the library output 
##(the plot from library output is shown). 
##The obtained results verified our model (y = 8.01157814 + 1.32199232 * x)

import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.linear_model import LinearRegression
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
X = data['Midterm mark'] 
y = data['Final mark']

X = X.values.reshape(-1,1) 
y = y.values.reshape(-1,1)

plt.scatter(X,y)
plt.show()


lin_reg = LinearRegression()

lin_reg_model = lin_reg.fit(X,y)

model_score = lin_reg_model.score(X, y)


log_message = f'The score of the model is: {model_score}.'
print(log_message)

log_message = f'The coef of the model is: {lin_reg_model.coef_}.'
print(log_message)

log_message = f'The intercept of the model is: {lin_reg_model.intercept_}.'
print(log_message) 


model_predict = lin_reg_model.predict(X)
log_message = f'The model predictions for the samne values are:\n X =\n {X}\n predictions = \n ${model_predict}.'
print(log_message) 
plt.scatter(X,y)
plt.plot(X, model_predict, color='red', linewidth=3)
plt.show()
print("The model is y = 8.01157814 + 1.32199232 * x")
# Out:
# The score of the model is: 0.5982684385776686.
# The coef of the model is: [[1.32199232]].
# The intercept of the model is: [8.01157814].
# The model predictions for the samne values are:
#  X =
#  [[32.5]
#  [53.4]
#  [61.5]
#  [47.5]
#  [59.8]
#  [55.1]
#  [52.2]
#  [39.3]
#  [48.1]
#  [52.6]
#  [45.4]
#  [54.4]
#  [44.2]
#  [58.2]
#  [56.7]
#  [49. ]
#  [44.7]
#  [60.3]
#  [45.6]
#  [38.8]
#  [66.2]
#  [65.4]
#  [47.5]
#  [41.6]
#  [51.8]
#  [59.4]
#  [57.3]
#  [63.6]
#  [46.7]
#  [50.6]
#  [52.2]
#  [35.6]
#  [42.4]
#  [58.2]
#  [57.5]
#  [45.4]
#  [61.9]
#  [33.1]
#  [36.4]
#  [37.7]
#  [44.6]
#  [43.3]
#  [50.1]
#  [43.9]
#  [63. ]
#  [32.7]
#  [40.2]
#  [53.6]
#  [33.9]
#  [64.7]
#  [38.1]
#  [44.5]
#  [40.6]
#  [41.7]
#  [51.1]
#  [55.1]
#  [41.4]
#  [62.5]
#  [49.2]
#  [41.1]
#  [41.2]
#  [50.2]
#  [52.4]
#  [50.1]
#  [33.6]
#  [39.6]
#  [56.1]
#  [57.4]
#  [60.3]
#  [35.7]
#  [31.6]
#  [53.7]
#  [46.7]
#  [43.1]
#  [70.3]
#  [44.5]
#  [57.5]
#  [36.9]
#  [55.8]
#  [39. ]
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 2000 times (iteration=2000) and learning rate is 0.0001 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=2000
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=2000
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  print(X_norm)
  
def run():
  learningRate=0.0001
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.0001
    init_b=0
    init_m=-0.5
    iterr=2000
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("2000 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    #plot after normalization
    print("2000 times updating iterrations regression line using normalization:")

    X_norm=(X-np.mean(X))/(np.std(X))
    plt.scatter(X_norm,y)
    plt.plot([min(X_norm), max(X_norm)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 2000:")
  plt.plot(range(2000),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 48.25549999999999
# After iterrations= 2000, error = 4.121147867408581e-15
# 4.121147867408581e-15
# 2000 times updating iterrations regression line:
# 2000 times updating iterrations regression line using normalization:
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=100) and learning rate is 0.0001 
## using Normalization 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)

### applying normalization
X_norm=(X-np.mean(X))/(np.std(X))
X=X_norm
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=100
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=100
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  return(X_norm)
  
def run():
  learningRate=0.0001
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.0001
    init_b=0
    init_m=-0.5
    iterr=100
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("100 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 100:")
  plt.plot(range(100),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 72.32059710868803
# After iterrations= 100, error = 69.87646202648436
# 69.87646202648436
# 100 times updating iterrations regression line:
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=2000) and learning rate is 0.0001 
### using normalization 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']
##normalizing feature X

X_norm=(X-np.mean(X))/(np.std(X))
X=X_norm

X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=2000
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  X=(X_norm)


def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=2000
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  

  
def run():
  learningRate=0.0001
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.0001
    init_b=0
    init_m=-0.5
    iterr=2000
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))
    
    print("2000 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 2000:")
  plt.plot(range(2000),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 72.32059710868803
# After iterrations= 2000, error = 35.459844672536335
# 35.459844672536335
# 2000 times updating iterrations regression line:
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=100) and learning rate is 0.1

import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=100
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=100
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  print(X_norm)
  
def run():
  learningRate=0.0001
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.0001
    init_b=0
    init_m=-0.5
    iterr=100
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("100 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 100:")
  plt.plot(range(100),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 48.25549999999999
# After iterrations= 100, error = 9.142907187253968e-07
# 9.142907187253968e-07
# 100 times updating iterrations regression line:
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 2000 times (iteration=2000) and learning rate is 0.1 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=2000
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=2000
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  print(X_norm)
  
def run():
  learningRate=0.1
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.1
    init_b=0
    init_m=-0.5
    iterr=2000
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("2000 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()

    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 2000:")
  plt.plot(range(2000),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 48.25549999999999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: RuntimeWarning: overflow encountered in add
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:59: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:59: RuntimeWarning: overflow encountered in add
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in subtract
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:62: RuntimeWarning: invalid value encountered in subtract
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=100) and learning rate is 0.1 
## using Normalization 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)

### applying normalization
X_norm=(X-np.mean(X))/(np.std(X))
X=X_norm
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=100
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)
  #plt.plot(range(100),errorplot)
  #plt.show()
  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=100
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  return(X_norm)
  
def run():
  learningRate=0.1
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.1
    init_b=0
    init_m=-0.5
    iterr=100
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("100 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 100:")
  plt.plot(range(100),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 72.32059710868803
# After iterrations= 100, error = 1.8002162249786125e-09
# 1.8002162249786125e-09
# 100 times updating iterrations regression line:
# ...

# %%
## The GD algorithm (an optimizer function which finds the best parameter of the model) is implemented
#the parameters (m and b) updated 100 times (iteration=2000) and learning rate is 0.1 
## using Normalization 
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
from io import StringIO

# Preprocessing Input data
data = pd.read_csv("https://raw.githubusercontent.com/tofighi/MachineLearning/master/datasets/student_marks.csv")
data.head()
X = data['Midterm mark'] 
y = data['Final mark']

X=X.values.reshape(-1,1)

### applying normalization
X_norm=(X-np.mean(X))/(np.std(X))
X=X_norm
y=y.values.reshape(-1,1)
plt.scatter(X, y, color = 'red')

plt.title('Midterm marks vs Final marks')
plt.xlabel('Midterm marks')
plt.ylabel('Final marks')
plt.show()
err=[]
#initialization
m= -0.5
b=0
n = float(len(X)) # Number of elements in X

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
plt.xlabel('Midterm mark')
plt.ylabel('Final mark')
print("Initial regression line b=0,m=-0.5,iterrnation = 0")
plt.show()


def error_line_points (b,m,X,y):
  iterr=2000
  error=0
  errorplot=[]
  for i in range(len(X)):
    
    error=(np.sum(y - np.absolute(m*X+b)))/len(X)
    errorplot.append(error)

  return error

def gradient_step (b_curr,m_curr,X,y,learningRate):
  n=len(X)
  iterr=2000
  b_grad=0
  m_grad=0

  for it in range(0,iterr):

    for i in range(0,n):
      m_grad += -(2/n) * X * (y - ((m_curr*X)+b_curr))  # Derivative wrt m
      b_grad += -(2/n) * (y - ((m_curr*X)+b_curr))  # Derivative wrt c
    
    m_new = m_curr - learningRate * m_grad  # Update m
    b_new = b_curr- learningRate * b_grad  # Update c
    
    #print (" gradient descent step : error = {} ".format(error_line_points (b_new,m_new,X,y) ))
    err.append(error_line_points (b_new,m_new,X,y))
    
    return [b_new,m_new]  

def gredient_descent (X,y, b_start,m_start,learningRate,iterr): 
  b=b_start
  m=m_start
  for i in range (iterr):
    b,m=gradient_step (b,m,X,y,learningRate)
  return[b,m]
  
def normalization(X):
  X_norm=(X-np.mean(X))/(np.std(X))
  return(X_norm)
  
def run():
  learningRate=0.1
  init_b=0
  init_m=-0.5
  iterr=0
      
if __name__ == '__main__':
  run()
  
  def run():
    learningRate=0.1
    init_b=0
    init_m=-0.5
    iterr=2000
    
    print ("Starting gradient descent at initial error = {0}".format(error_line_points (init_b,init_m,X,y) ) )
    
    # calling gredient descent to decrease error
    [b, m] =gredient_descent(X,y, init_b, init_m, learningRate, iterr)
    print ("After iterrations= {0}, error = {1}".format(iterr, error_line_points(b, m, X,y)))
    print(error_line_points(b, m, X,y))

    print("2000 times updating iterrations regression line:")
    plt.scatter(X,y)
    plt.plot([min(X), max(X)], [min(m*X+b), max(m*X+b)], color='red')  # regression line
    plt.xlabel('Midterm mark')
    plt.ylabel('Final mark')
    plt.show()
    
    
    
if __name__ == '__main__':
  
  run()
  print("errors= {}".format(err))
  #plot cost - iterr
  print("Error at each iteration (from initial point to iteration 2000:")
  plt.plot(range(2000),err)
  plt.xlabel('Interation')
  plt.ylabel('Error')
  plt.show()
# Out:
# Initial regression line b=0,m=-0.5,iterrnation = 0
# Starting gradient descent at initial error = 72.32059710868803
# After iterrations= 2000, error = 1.0587086762825493e-14
# 1.0587086762825493e-14
# 2000 times updating iterrations regression line:
# ...
